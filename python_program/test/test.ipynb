# %%
import os

raw_data_folder = "/home/amos/VERTECS/python_program/x-band-software/mock_data/"

os.listdir(raw_data_folder)
# Out:
# ['F20250109155526.bin',
#  'C20250110164341.bin',
#  'C20250110163605.bin',
#  'F20250120132129.bin',
#  'F20250109124843.bin',
#  'F20250109130351.bin',
#  'C20250110164457.bin',
#  'F20250109125804.bin',
#  'F20250109155612.bin',
#  'F20250109125426.bin']
